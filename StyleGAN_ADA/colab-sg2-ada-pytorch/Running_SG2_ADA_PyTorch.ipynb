# %% [markdown]
# # StyleGAN2-ADA-PyTorch
#
# Attributions of the code to: Derrick-Schultz
#
# Github: https://github.com/dvschultz/stylegan2-ada-pytorch
#
# We used same code, different dataset and tested hyperparameters.

# %% [markdown]
# ## Setup
#
# Setting the lab machines with depedencies.
#
# We recommend to create a separate conda environment.

# %%
# !which nvcc
# !module load cuda-11.1
# !which nvcc
# Out:
# nvcc not found
# zsh:1: command not found: module
# nvcc not found

# %%
# !conda install pytorch torchvision torchaudio cudatoolkit=11.3 -c pytorch

# !pip install psutil scipy

# !pip install click opensimplex requests tqdm pyspng ninja imageio-ffmpeg==0.4.3

# !pip install opensimplex

# !pip install ninja opensimplex torch==1.7.1 torchvision==0.8.2

# %%
# !nvidia-smi
# Out:
# Mon Nov 29 19:49:39 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 470.74       CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 6000     On   | 00000000:73:00.0  On |                  Off |
# | 33%   50C    P5    26W / 260W |    471MiB / 24197MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## Install repo
#
# Input the email user of MBZUAI in order to install the repo in the machine.
#
# Example: ariana.venegas@mbzuai.ac.ae would be only -> ariana.venegas

# %%
username_lab = "ariana.venegas"

# %% [markdown]
# You can do the following step (below) and put the weights in results, or download the zip from: https://mbzuaiac-my.sharepoint.com/:u:/g/personal/ariana_venegas_mbzuai_ac_ae/EToiZYOXKtpGq93fga6OR7wBwbBuxH3WV7WX6f9aTT2dyQ?e=qqdjkF and put it inside (pasting the zip and unzip there).
#
#
# ```bash
# cd /home/{username_lab}/Documents/colab-sg2-ada-pytorch
# ```
#
# have in mind to change the {username_lab} like
#
#
# ```bash
# cd /home/ariana.venegas/Documents/colab-sg2-ada-pytorch
# ```

# %%
import os
if os.path.isdir("/home/"+username_lab+"/Documents/colab-sg2-ada-pytorch"):
    dir_ada = "/home/"+username_lab+"/Documents/colab-sg2-ada-pytorch/stylegan2-ada-pytorch"
    # %cd $dir_ada
elif os.path.isdir("/home/"+username_lab):
    #install script
    dir_doc =  "/home/"+username_lab+"/Documents/"
    # %cd $dir_doc
    # !mkdir colab-sg2-ada-pytorch
    # %cd colab-sg2-ada-pytorch
    # !git clone https://github.com/dvschultz/stylegan2-ada-pytorch
    # %cd stylegan2-ada-pytorch
    # !mkdir downloads
    # !mkdir datasets
    # !mkdir pretrained
    # !gdown --id 1-5xZkD8ajXw1DdopTkH_rAoCsD72LhKU -O /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/pretrained/wikiart.pkl
else:
    # !git clone https://github.com/dvschultz/stylegan2-ada-pytorch
    # %cd stylegan2-ada-pytorch
    # !mkdir downloads
    # !mkdir datasets
    # !mkdir pretrained
    # %cd pretrained
    # !gdown --id 1-5xZkD8ajXw1DdopTkH_rAoCsD72LhKU
    # %cd ../
# Out:
# [Errno 2] No such file or directory: '/Users/arianabermudezDocuments/'
# /Users/arianabermudez/Documents/results_from_ssh
# /Users/arianabermudez/Documents/results_from_ssh/colab-sg2-ada-pytorch
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 524, done.
# remote: Total 524 (delta 0), reused 0 (delta 0), pack-reused 524
# Receiving objects: 100% (524/524), 8.41 MiB | 2.85 MiB/s, done.
# Resolving deltas: 100% (296/296), done.
# /Users/arianabermudez/Documents/results_from_ssh/colab-sg2-ada-pytorch/stylegan2-ada-pytorch
# zsh:1: command not found: gdown

# %% [markdown]
# ## Dataset Preparation
#
# Upload a .zip of square images to the `datasets` folder. In our case we have 300 and 600 images dataset.

# %% [markdown]
# ## Train model

# %% [markdown]
# Below are a series of variables you need to set to run the training. You probably won’t need to touch most of them.
#
# * `dataset_path`: this is the path to your .zip file
# * `resume_from`: if you’re starting a new dataset I recommend `'ffhq1024'` or `'./pretrained/wikiart.pkl'`
# * `mirror_x` and `mirror_y`: Allow the dataset to use horizontal or vertical mirroring.

# %% [markdown]
# ### First experiment
#
# Had good results, not enough to trick people to know if it was computer generated or human made. Around kimg/epoch 14,000 went to mode collapse. (This ran for a week and a half)
#
# Augmentation were: blit and geometric.
#
#
# Results at ±2500kimg were the best.
#
#
# Had mode collapse in ±13000 kimg.

# %%
#only 300 images for dataset
dataset_path = '/home/'+username_lab+'/Documents/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/datasets/Monet_pics_only.zip'
resume_from = '/home/'+username_lab+'/Documents/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/pretrained/wikiart.pkl'
aug_strength =  0
train_count = 0
mirror_x = True
#mirror_y = False #this is commented because it flips the images, not recommended

#optional: you might not need to edit these
gamma_value = 50.0
augs = 'bg' 
config = '24gb-gpu'
snapshot_count = 12

# %%
# !python train.py --gpus=1 --cfg=$config --metrics=None --outdir=./results --data=$dataset_path --snap=$snapshot_count --resume=$resume_from --augpipe=$augs --initstrength=$aug_strength --gamma=$gamma_value --mirror=$mirror_x --mirrory=False --nkimg=$train_count

# %% [markdown]
# ### Second experiment
# Using gamma from CIFAR-10. Bad results, the generator is not learning (because loss decreases overtime).
#
# Augmentation were: blit and geometric. Ran around ±800 kimg/epochs.

# %%
#only 300 images for dataset
dataset_path = '/home/'+username_lab+'/Documents/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/datasets/Monet_pics_only.zip'
resume_from = '/home/'+username_lab+'/Documents/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/results/wikiart.pkl' 
aug_strength =  0
train_count = 0 
mirror_x = True


#optional: you might not need to edit these
gamma_value = 0.10
augs = 'bg'
config = '24gb-gpu'
snapshot_count = 12

# %%
# !python train.py --gpus=1 --cfg=$config --metrics=None --outdir=./results --data=$dataset_path --snap=$snapshot_count --resume=$resume_from --augpipe=$augs --initstrength=$aug_strength --gamma=$gamma_value --mirror=$mirror_x --mirrory=False --nkimg=$train_count

# %% [markdown]
# ### Third experiment
# Best performance out of the experiments. No mode collapse. Question for next iteration would be finding which is the min images before mode collapse.
#
# Same hyper parameters that first experiment but more images for training. Ran around ±14,000 kimg/epochs.

# %%
#Balanced dataset, 600 images for dataset
dataset_path = '/home/'+username_lab+'/Documents/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/datasets/Monet_pics_only.zip'
resume_from = '/home/'+username_lab+'/Documents/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/results/wikiart.pkl' 
aug_strength =  0
train_count = 0 
mirror_x = True


#optional: you might not need to edit these
gamma_value = 50
augs = 'bg'
config = '24gb-gpu'
snapshot_count = 12

# %%
# !python train.py --gpus=1 --cfg=$config --metrics=None --outdir=./results --data=$dataset_path --snap=$snapshot_count --resume=$resume_from --augpipe=$augs --initstrength=$aug_strength --gamma=$gamma_value --mirror=$mirror_x --mirrory=False --nkimg=$train_count

# %% [markdown]
# ### Fourth experiment
# Testing augmentations only. Not enough kimgs to compare because limitations of using only 1 machine per student.

# %%
#Balanced dataset, 600 images for dataset
dataset_path = '/home/'+username_lab+'/Documents/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/datasets/Monet_pics_only.zip'
resume_from = '/home/'+username_lab+'/Documents/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/results/wikiart.pkl' 
aug_strength =  0
train_count = 0 
mirror_x = True


#optional: you might not need to edit these
gamma_value = 50
augs = 'color'
config = '24gb-gpu'
snapshot_count = 12

# %%
# !python train.py --gpus=1 --cfg=$config --metrics=None --outdir=./results --data=$dataset_path --snap=$snapshot_count --resume=$resume_from --augpipe=$augs --initstrength=$aug_strength --gamma=$gamma_value --mirror=$mirror_x --mirrory=False --nkimg=$train_count
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 12,
#   "network_snapshot_ticks": 12,
#   "metrics": [],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/home/ariana.venegas/Documents/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/datasets/Balanced_normal_and_monet.zip",
#     "use_labels": false,
#     "max_size": 600,
#     "xflip": true,
#     "resolution": 256
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 8
#     },
#     "synthesis_kwargs": {
#       "channel_base": 32768,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
# ...

# %% [markdown]
# ## Testing/Inference
#
# Also known as "Inference", "Evaluation" or "Testing" the model. This is the process of usinng your trained model to generate new material, usually images or videos.

# %% [markdown]
# ### Generate Single Images - from original github
#
# `--network`: Make sure the `--network` argument points to your .pkl file. (My preferred method is to right click on the file in the Files pane to your left and choose `Copy Path`, then paste that into the argument after the `=` sign).
#
# `--seeds`: This allows you to choose random seeds from the model. Remember that our input to StyleGAN is a 512-dimensional array. These seeds will generate those 512 values. Each seed will generate a different, random array. The same seed value will also always generate the same random array, so we can later use it for other purposes like interpolation.
#
# `--truncation`: Truncation, well, truncates the latent space. This can have a subtle or dramatic affect on your images depending on the value you use. The smaller the number the more realistic your images should appear, but this will also affect diversity. Most people choose between 0.5 and 1.0, but technically it's infinite.

# %%
network_path = '/home/'+username_lab+'/Documents/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/results/ID03-network-snapshot-002496.pkl'

# %%
# !python generate.py --outdir=/content/out/images/ --trunc=0.8 --size=256-256 --seeds=0 --network=$network_path
